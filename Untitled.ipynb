# %%
import pandas as pd

# %%
df = pd.read_csv('out/metrics.csv')

# %%
df
# Out:
#             file    wer       cer  seq_match_ratio  jiwer_wer  jiwer_cer  \
# 0     output.txt  1.000  0.558824         0.737864      1.000   0.585366
# 1   output01.txt  0.250  0.088235         0.939759      0.250   0.073171
# 2   output02.txt  0.250  0.117647         0.928571      0.250   0.097561
# 3    output1.txt  0.875  0.529412         0.588235      0.875   0.512195
# 4   output10.txt  0.250  0.147059         0.891566      0.250   0.121951
# 5    output2.txt  1.000  0.529412         0.560976      1.000   0.536585
# 6    output3.txt  0.625  0.323529         0.752941      0.625   0.292683
# 7    output4.txt  0.625  0.352941         0.750000      0.625   0.341463
# 8    output5.txt  0.625  0.441176         0.696629      0.625   0.390244
# 9    output6.txt  0.375  0.264706         0.850575      0.375   0.243902
# 10   output7.txt  0.500  0.176471         0.867470      0.500   0.170732
# 11   output8.txt  0.500  0.205882         0.853659      0.500   0.170732
# ...
